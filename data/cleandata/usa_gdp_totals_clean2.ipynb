# %%
import numpy as np
import pandas as pd
from pathlib import Path
import csv

# %%
gdp_path = Path("../rawdata/Howard-USA-GDP-Totals.csv")

# %%
gdp_df = pd.read_csv(gdp_path, skiprows=4)

# %%
gdp_df = gdp_df.drop([60,61,62,63])

# %%
gdp_df = gdp_df.drop(columns=["GeoFips"])

# %%
gdp_df
# Out:
#                  GeoName       1997       1998       1999        2000  \
# 0        United States *  8577552.0  9062817.0  9630663.0  10252347.0
# 1                Alabama   104716.9   110181.3   115833.1    120132.9
# 2                 Alaska    25800.0    24227.6    24779.3     26815.8
# 3                Arizona   132290.9   143286.2   155282.6    164609.9
# 4               Arkansas    59826.9    62397.8    66791.2     68740.4
# 5             California  1071327.2  1147944.3  1247734.4   1366166.5
# 6               Colorado   136916.6   150364.4   164132.0    180693.3
# 7            Connecticut   138548.4   145432.7   152353.9    165822.4
# 8               Delaware    33400.0    37065.1    40427.3     43515.9
# 9   District of Columbia    52483.3    54780.2    58751.3     61033.2
# 10               Florida   401688.9   429188.3   456797.9    488466.1
# 11               Georgia   242681.6   265321.7   289446.6    306019.9
# ...

# %%
# create states & DC only dataframe
states_df = gdp_df[1:52]

# %%
# create regions dataframe
regions_df = gdp_df[52:60]

# %%
#create whole country dataframe

country_total_df = gdp_df[0:1]
country_total_df
# Out:
#            GeoName       1997       1998       1999        2000        2001  \
# 0  United States *  8577552.0  9062817.0  9630663.0  10252347.0  10581822.0
#
#          2002        2003        2004        2005  ...        2010  \
# 0  10936418.0  11458246.0  12213730.0  13036637.0  ...  14992052.0
#
#          2011        2012        2013        2014        2015        2016  \
# 0  15542582.0  16197007.0  16784851.0  17527258.0  18238301.0  18745075.0
#
#          2017        2018        2019
# 0  19542980.0  20611861.0  21433226.0
#
# [1 rows x 24 columns]

# %%
import plotly.express as px
